# %% [markdown]
# # **Lec01.변수**

# %% [markdown]
# >변수란 : 값을 저장하는 공간 (메모리 4바이트 주소)

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %% [markdown]
# ## 타입
# * phython은 타입 지정을 하지 않는다.

# %% [markdown]
# * 숫자 : int a = 10
# * 문자열: string a = "안녕"
# * 글자 : char a = '나'
# * 배열 : a[] = {1,2,3,4,5,6,7}

# %%
"안녕" * 2
# Out:
# '안녕안녕'

# %% [markdown]
# ## 컬렉션
# * <font color=red><b>리스트 : []
# * <font color=red><b>튜플 : () 생성, 조회만 가능, 수정삭제불가
# * <font color=red><b>딕셔너리 : {}

# %% [markdown]
# ### **C(Creat)**

# %%
mylist = [1,2,3,"가","나"]
print(mylist)
# Out:
# [1, 2, 3, '가', '나']

# %%
mytuple = (1,2,3,"가","나")
print(mytuple)
# Out:
# (1, 2, 3, '가', '나')

# %%
mydict = {"등수":1 , "성별":2 , "등급":"가"}
print(mydict)
# Out:
# {'등수': 1, '성별': 2, '등급': '가'}

# %%
mylist = [2,4,6,"놈", "놈"]
print(mylist)
# Out:
# [2, 4, 6, '놈', '놈']

# %%
mylist.append("카")
print(mylist)
# Out:
# [2, 4, 6, '놈', '놈', '카']

# %%
mytuple = (2,4,6,"놈", "놈")
print(mytuple)
# Out:
# (2, 4, 6, '놈', '놈')

# %%
mydict = {"이상한놈":1 , "나쁜놈":2 , "착한놈":3}
print(mydict)
# Out:
# {'이상한놈': 1, '나쁜놈': 2, '착한놈': 3}

# %% [markdown]
# ### **R(Read)**
# * 리스트/튜플 : 인덱스(index.. 번째)0부터 시작
# * 딕셔너리 : 키(key)

# %%
print(mylist)
# Out:
# [2, 4, 6, '놈', '놈', '카']

# %%
mylist
# Out:
# [2, 4, 6, '놈', '놈', '카']

# %%
print(mylist[0])
print(mylist[5])
print(mylist[-1])
print(mylist[0:3]) #슬라이싱 :  0이상 3미만
print(mytuple[0])
# Out:
# 2
# 카
# 카
# [2, 4, 6]
# 2

# %%
print(mydict.keys() )
print(mydict.values() )
print(mydict.items() )
# Out:
# dict_keys(['이상한놈', '나쁜놈', '착한놈'])
# dict_values([1, 2, 3])
# dict_items([('이상한놈', 1), ('나쁜놈', 2), ('착한놈', 3)])

# %%
mydict['이상한놈'] , mydict['나쁜놈']
# Out:
# (1, 2)

# %% [markdown]
# ### **U(Update)**

# %%
mylist
# Out:
# [2, 4, 6, '놈', '놈', '카']

# %%
mylist[0] = 1111
mylist
# Out:
# [1111, 4, 6, '놈', '놈', '카']

# %%
mydict
# Out:
# {'이상한놈': 1, '나쁜놈': 2, '착한놈': 3}

# %%
mydict['이상한놈'] = 10
mydict
# Out:
# {'이상한놈': 10, '나쁜놈': 2, '착한놈': 3}

# %% [markdown]
# ### **D(Delete)**

# %%
mylist
# Out:
# [1111, 4, 6, '놈', '놈', '카']

# %% [markdown]
# # **외운거**

# %%
mylist = [1,2,3,"가","나"]
print(mylist)
# Out:
# [1, 2, 3, '가', '나']

# %%
mytuple = (1,2,3,"가","나")
print(mytuple)
# Out:
# (1, 2, 3, '가', '나')

# %%
mydict = {"등수":1 , "성별":2 , "등급":"가"}
print(mydict)
# Out:
# {'등수': 1, '성별': 2, '등급': '가'}
