# %% [markdown]
# # **Lec06. 패키지 & 모듈 & 클래스 & 함수**

# %% [markdown]
# > <b>REST(Representational State Transfer)</b> <br>
# : HTTP 프로토콜을 기반으로 웹 자원(데이터)을 주고받는 소프트웨어 아키텍처 <br>
# : 1) 웹 서비스<br>
# : 2) 인증키<br>
# : 3) 데이터포맷은 일반적으로 JSON(JavaScript Object Notation)/XML    <br>
#      - JSON 표기 : {"키" : "값", "키" : "값"}<br>
# : 4) 비동기통신이 일반적

# %%
``` python

from 패키지.모듈 import 클래스
from 패키지.모듈 import 함수, 함수2  ...  *

from       모듈 import 클래스       ---- 클래스.add(4,5)
from       모듈 import 함수, add    ---- add(4,5)
                import 모듈         ---- 모듈.add(4,5)
                import 모듈 as aa   ---- aa.add(4,5)

# %%
mydic = {"result" : [1,  {"age": [30,20,10] } ,  [10,20]  ] }
print(  mydic["result"] )
# Out:
# [1, {'age': [30, 20, 10]}, [10, 20]]

# %%
mydic = {"result" :       [1,  {"age": [30,20,10] } ,  [10,20]  ]        }
print(  mydic["result"] )
print("--"*20)
print(  mydic["result"][0] )
print(  mydic["result"][1] )
print(  mydic["result"][2] )
print("--"*20)
print(  mydic["result"][1]['age'] )
print(  mydic["result"][1]['age'][0] )
# Out:
# [1, {'age': [30, 20, 10]}, [10, 20]]
# ----------------------------------------
# 1
# {'age': [30, 20, 10]}
# [10, 20]
# ----------------------------------------
# [30, 20, 10]
# 30

# %%
mydic = {
  "user_id"           : 9876543211234,
  "shipping_addresses": [
                        {
                          "id": 319,
                          "name": "회사",
                          "base_address": "경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)",
                          "receiver_phone_number1": "031-123-2345"
                            },
                        {
                          "id": 320,
                          "name": "회사",
                          "base_address": "경기 성남시 분당구 삼평동 680 (삼평동, 에이치스퀘어 에스동)",
                          "receiver_phone_number1": "010-0056-1234"
                            }
                              ]
                            }
print(mydic["shipping_addresses"][0]["base_address"])
print(mydic["shipping_addresses"][0]["id"])
print(mydic["shipping_addresses"][1]["receiver_phone_number1"])
# Out:
# 경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)
# 319
# 010-0056-1234

# %%
mydic = [
  {
    "id": 1399634384,
    "connected_at": "2020-07-06T09:55:51Z",
    "kakao_account": {
      "profile": {
        "nickname": "춘식이",
      },
      "email": "sweetpotato@kakao.com"
    }
  },
  {
    "id": 1406264199,
    "connected_at": "2020-07-14T06:15:36Z",
    "kakao_account": {
   
      "profile": {
        "nickname": "나비",
      },
      "email": "abc@kakao.com"
    }
  }
]
print(mydic[0]["kakao_account" ]["profile"]["nickname"])
print(mydic[1]["kakao_account" ]["profile"]["nickname"])
# Out:
# 춘식이
# 나비

# %%
for i,v  in enumerate (mydic):
    print(mydic[i]["kakao_account"]["profile"]["nickname"])
# Out:
# 춘식이
# 나비

# %%
mydic = {"result" : 10 }
print(mydic["resu
# Out:
# 10

# %%
mydic = {"result" : '홍' }
print(mydic["result"])
# Out:
# 홍

# %%
mydic = {"result" : [1,2,3] }
print(mydic["result"])
# Out:
# [1, 2, 3]

# %%
mydic = {"result" : [1,2,'홍'] }
print(mydic["result"])
# Out:
# [1, 2, '홍']

# %%
mydic = {"result" : [1,  {"age": [30,20,10] } ,  [10,20]  ] }
print(  mydic["result"] )
# Out:
# [1, {'age': [30, 20, 10]}, [10, 20]]

# %%
mydic = {"result" :       [1,  {"age": [30,20,10] } ,  [10,20]  ]        }
print(  mydic["result"] )
print("--"*20)
print(  mydic["result"][0] )
print(  mydic["result"][1] )
print(  mydic["result"][2] )
print("--"*20)
print(  mydic["result"][1]['age'] )
print(  mydic["result"][1]['age'][0] )
print(  mydic["result"][1]['age'][1] )
print(  mydic["result"][2][1] )
# Out:
# [1, {'age': [30, 20, 10]}, [10, 20]]
# ----------------------------------------
# 1
# {'age': [30, 20, 10]}
# [10, 20]
# ----------------------------------------
# [30, 20, 10]
# 30
# 20
# 20

# %%
mydic = {
  "user_id": 9876543211234,
  "shipping_addresses": [
    {
      "id": 319,
      "name": "회사",
      "base_address": "경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)",
      "receiver_phone_number1": "031-123-2345"
    },
    {
      "id": 320,
      "name": "회사",
      "base_address": "경기 성남시 분당구 삼평동 680 (삼평동, 에이치스퀘어 에스동)",
      "receiver_phone_number1": "010-0056-1234"
    }
  ]
}
print ( mydic["shipping_addresses"][0]["base_address"] )
# Out:
# 경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)

# %%
mydic = [
  {
    "id": 1399634384,
    "connected_at": "2020-07-06T09:55:51Z",
    "kakao_account": {
      "profile": {
        "nickname": "춘식이",
      },
      "email": "sweetpotato@kakao.com"
    }
  },
  {
    "id": 1406264199,
    "connected_at": "2020-07-14T06:15:36Z",
    "kakao_account": {
   
      "profile": {
        "nickname": "나비",
      },
      "email": "abc@kakao.com"
    }
  }
]
print(mydic[0]["kakao_account"]["profile"]["nickname"])
print(mydic[1]["kakao_account"]["profile"]["nickname"])
# Out:
# 춘식이
# 나비

# %%
for v in mydic : 
    print( v["kakao_account"]["profile"]["nickname"] ) #많은 수에서 찾는 법
# Out:
# 춘식이
# 나비

# %%
for i, v in enumerate(mydic) : 
    print(mydic[i]["kakao_account"]["profile"]["nickname"] ) #많은 수에서 찾는 법
# Out:
# 춘식이
# 나비

# %% [markdown]
# # **[실습] youtube-search-python API 활용**
# * pip install youtube-search-python
# * https://github.com/alexmercerind/youtube-search-python

# %%
from youtubesearchpython import VideosSearch

videosSearch = VideosSearch('나루토', limit = 2)

print(videosSearch.result())
# Out:
# {'result': [{'type': 'video', 'id': 'FbEcEWGGB0g', 'title': '우리의 학창 시절을 함께한 애니🔥마지막엔 모두가 울 수밖에 없었던 ‘나루토’ 이야기', 'publishedTime': '1 month ago', 'duration': '3:26:41', 'viewCount': {'text': '436,402 views', 'short': '436K views'}, 'thumbnails': [{'url': 'https://i.ytimg.com/vi/FbEcEWGGB0g/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC0dTta1uRrNkAAc2jFLN1T9JMLwQ', 'width': 360, 'height': 202}, {'url': 'https://i.ytimg.com/vi/FbEcEWGGB0g/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCl8M_mSZJxzRIDTygbpGY_jpNPaQ', 'width': 720, 'height': 404}], 'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/FbEcEWGGB0g/mqdefault_6s.webp?du=3000&sqp=CNjejtQG&rs=AOn4CLCUx-le33Hn20sBBOy81vqrecSrUA', 'width': 320, 'height': 180}, 'descriptionSnippet': [{'text': '본 영상은 단순 재업로드 또는 재사용 콘텐츠가 아닙니다. 본 채널의 모든 영상은 스토리 재구성, 내러티브 추가, 편집 연출을 통해 제작\xa0...'}], 'channel': {'name': '깡스필름', 'id': 'UCKuUYspmBI6-dNB1YebhD3w', 'thumbnails': [{'url': 'https://yt3.ggpht.com/si_l4hKL8v-U7-7kcuiK8iyenxbLzz6eZ4cA_q-EQg9UxMfrQL5BFw2vS9EItEYTDtcMb5OS=s68-c-k-c0x00ffffff-no-rj', 'width': 68, 'height': 68}], 'link': 'https://www.youtube.com/channel/UCKuUYspmBI6-dNB1YebhD3w'}, 'accessibility': {'title': '우리의 학창 시절을 함께한 애니🔥마지막엔 모두가 울 수밖에 없었던 ‘나루토’ 이야기 3 hours, 26 minutes', 'duration': '3 hours, 26 minutes, 41 seconds'}, 'link': 'https://www.youtube.com/watch?v=FbEcEWGGB0g', 'shelfTitle': None}, {'type': 'video', 'id': 'hIwGBOexa5w', 'title': '【MAD】  나루토 × 실루엣 / ナルト × シルエット', 'publishedTime': '3 years ago', 'duration': '4:05', 'viewCount': {'text': '7,470,557 views', 'short': '7.4M views'}, 'thumbnails': [{'url': 'https://i.ytimg.com/vi/hIwGBOexa5w/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAcLAN1qm5CLNO64QdSZT1nLJdxhQ', 'width': 360, 'height': 202}, {'url': 'https://i.ytimg.com/vi/hIwGBOexa5w/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCu8FcolAqcjcteBvuWWoQJjPEmqQ', 'width': 720, 'height': 404}], 'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/hIwGBOexa5w/mqdefault_6s.webp?du=3000&sqp=CLTbjtQG&rs=AOn4CLAIh6vQxgLWJRMlokEdl3KBm_JAjA', 'width': 320, 'height': 180}, 'descriptionSnippet': [{'text': '나루토', 'bold': True}, {'text': ' #실루엣 #ナルト_シルエット 미안하다 이거 보여주려고 어그로끌었다..'}], 'channel': {'name': 'Hokori', 'id': 'UCHmStrOsTAIbsCn-6Gk5RrA', 'thumbnails': [{'url': 'https://yt3.ggpht.com/yXU7Na-w45r9ScukfqWl2GBQKnTJFgbR8bkTe1xl1wwcZQ_lx0WyotBcLPbvMo7sw7a9es9eAw=s68-c-k-c0x00ffffff-no-rj', 'width': 68, 'height': 68}], 'link': 'https://www.youtube.com/channel/UCHmStrOsTAIbsCn-6Gk5RrA'}, 'accessibility': {'title': '【MAD】  나루토 × 실루엣 / ナルト × シルエット 4 minutes, 5 seconds', 'duration': '4 minutes, 5 seconds'}, 'link': 'https://www.youtube.com/watch?v=hIwGBOexa5w', 'shelfTitle': None}]}

# %%
from youtubesearchpython import VideosSearch

videosSearch = VideosSearch('NoCopyrightSounds', limit = 2)

print(videosSearch.result())

# %%
from youtubesearchpython import VideosSearch

videosSearch = VideosSearch('뽀로로', limit = 2)

from pprint import pprint

pprint(videosSearch.result())
# Out:
# {'result': [{'accessibility': {'duration': None,
#                                'title': '뽀롱뽀롱 뽀로로 9기 전편 연속 재생 | 뽀로로 이야기 | 뽀로로 '
#                                         '인기본편 | 뽀롱뽀롱뽀로로'},
#              'channel': {'id': 'UCPUeGC_AL-OnDQORKhRm6iA',
#                          'link': 'https://www.youtube.com/channel/UCPUeGC_AL-OnDQORKhRm6iA',
#                          'name': 'Pororo Korean Official',
#                          'thumbnails': [{'height': 68,
#                                          'url': 'https://yt3.ggpht.com/lZhJCaZloizCCPM4KbppoLbFHpD-mR-byhrB2KQYyN8EJzeAPECYwe4Kco4JzxjBlMKlfM__tw=s88-c-k-c0x00ffffff-no-rj',
#                                          'width': 68}]},
#              'descriptionSnippet': [{'bold': True, 'text': '뽀로로'},
#                                     {'text': '의 새로운 영상을 가장 빠르게 만나는 방법! 지금 바로 '
#                                              '뽀롱뽀롱 '},
#                                     {'bold': True, 'text': '뽀로로'},
#                                     {'text': ' 공식 유튜브 채널 [구독]버튼을 눌러주세요. ☆'},
#                                     {'bold': True, 'text': '뽀로로'},
#                                     {'text': '\xa0...'}],
#              'duration': None,
#              'id': 'ZshH8LC5zXA',
#              'link': 'https://www.youtube.com/watch?v=ZshH8LC5zXA',
#              'publishedTime': None,
#              'richThumbnail': None,
#              'shelfTitle': None,
#              'thumbnails': [{'height': 202,
#                              'url': 'https://i.ytimg.com/vi/ZshH8LC5zXA/hq720.jpg?v=6a7ead81&sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCUsqWyo_mR5PXjJsPwQhHee-hgng',
#                              'width': 360},
#                             {'height': 404,
#                              'url': 'https://i.ytimg.com/vi/ZshH8LC5zXA/hq720.jpg?v=6a7ead81&sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB3pyoaHrJrPbp0KoJZcqtqEZsBtg',
#                              'width': 720}],
#              'title': '뽀롱뽀롱 뽀로로 9기 전편 연속 재생 | 뽀로로 이야기 | 뽀로로 인기본편 | 뽀롱뽀롱뽀로로',
#              'type': 'video',
#              'viewCount': {'short': None, 'text': None}},
#             {'accessibility': {'duration': '1 hour, 6 minutes, 21 seconds',
#                                'title': '뽀로로 이야기 | 이야! 여름이다! 물놀이 이야기 모음집 '
#                                         '(+1시간) | 티비로 몰아보는 뽀로로 인기 에피소드 | 뽀로로 '
#                                         '1시간 이어보기 1 hour, 6 minutes'},
#              'channel': {'id': 'UCyyCXaPt37-4rTpDvL6niMA',
#                          'link': 'https://www.youtube.com/channel/UCyyCXaPt37-4rTpDvL6niMA',
#                          'name': '뽀롱뽀롱 뽀로로 l 이야기・동화',
#                          'thumbnails': [{'height': 68,
#                                          'url': 'https://yt3.ggpht.com/B2z79GE75yn5BEQ788O5Zk1Rou3HWSk7uPo5VOqMjwqUYBbE4FMK5kMCX_z2DvFAgbp4lQOGsQ=s68-c-k-c0x00ffffff-no-rj',
#                                          'width': 68}]},
#              'descriptionSnippet': [{'bold': True, 'text': '뽀로로'},
#                                     {'text': ' 이야기를 좋아하는 친구라면 구독버튼 꾸욱!'}],
#              'duration': '1:06:21',
#              'id': 'K4B_yNbg5lQ',
#              'link': 'https://www.youtube.com/watch?v=K4B_yNbg5lQ',
#              'publishedTime': '1 year ago',
#              'richThumbnail': {'height': 180,
#                                'url': 'https://i.ytimg.com/an_webp/K4B_yNbg5lQ/mqdefault_6s.webp?du=3000&sqp=CLCsj9QG&rs=AOn4CLB0OY2-nAVJbD6PAdDc3xHCv97E6w',
#                                'width': 320},
#              'shelfTitle': None,
#              'thumbnails': [{'height': 202,
#                              'url': 'https://i.ytimg.com/vi/K4B_yNbg5lQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBa69g21hiEIVzuMxF96bl7Y8RZuw',
#                              'width': 360},
#                             {'height': 404,
#                              'url': 'https://i.ytimg.com/vi/K4B_yNbg5lQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCireOXWPrUUhTgE_cM10RrcoJoag',
#                              'width': 720}],
#              'title': '뽀로로 이야기 | 이야! 여름이다! 물놀이 이야기 모음집 (+1시간) | 티비로 몰아보는 뽀로로 '
#                       '인기 에피소드 | 뽀로로 1시간 이어보기',
#              'type': 'video',
#              'viewCount': {'short': '2.1M views', 'text': '2,120,281 views'}}]}

# %%
result = videosSearch.result()

print(result["result"][0]["title"])
# Out:
# 뽀롱뽀롱 뽀로로 9기 전편 연속 재생 | 뽀로로 이야기 | 뽀로로 인기본편 | 뽀롱뽀롱뽀로로

# %%
result = videosSearch.result()

print(result["result"][0]["link"])
# Out:
# https://www.youtube.com/watch?v=ZshH8LC5zXA

# %%
result = videosSearch.result()

print(result["result"][0]['channel']["name"])
# Out:
# Pororo Korean Official

# %%
result = videosSearch.result()

print(result["result"][0]['channel']["thumbnails"][0])
# Out:
# {'url': 'https://yt3.ggpht.com/lZhJCaZloizCCPM4KbppoLbFHpD-mR-byhrB2KQYyN8EJzeAPECYwe4Kco4JzxjBlMKlfM__tw=s88-c-k-c0x00ffffff-no-rj', 'width': 68, 'height': 68}

# %%
# from youtubesearchpython.search import VideosSearch
from youtubesearchpython import VideosSearch
from pprint import pprint

res = VideosSearch('뽀로로', limit = 5)
# pprint(res.result())

data = res.result()
for v in data['result'] :
    print(v['title'])
    print(v['thumbnails'][0]['url'])
    print(v['link'])
    print("---"*20)
# Out:
# 뽀롱뽀롱 뽀로로 9기 전편 연속 재생 | 뽀로로 이야기 | 뽀로로 인기본편 | 뽀롱뽀롱뽀로로
# https://i.ytimg.com/vi/ZshH8LC5zXA/hq720.jpg?v=6a7ead81&sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCUsqWyo_mR5PXjJsPwQhHee-hgng
# https://www.youtube.com/watch?v=ZshH8LC5zXA
# ------------------------------------------------------------
# 뽀로로 이야기 | 연휴에 몰아보는 뽀로로 인기 본편 | TV로 보는 뽀로로 | 뽀로로 3시간 이어보기 | 뽀롱뽀롱 뽀로로
# https://i.ytimg.com/vi/qwIEziCjSUo/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDvyvpX_Do78-GIyIQkwtBz59StMw
# https://www.youtube.com/watch?v=qwIEziCjSUo
# ------------------------------------------------------------
# 뽀로로 이야기 | 뽀롱뽀롱 세균 퇴치 | 뽀로로 8기 | TV로 보는 뽀로로 | 주말에 보는 뽀로로 | 뽀로로 3시간 | 뽀롱뽀롱 뽀로로
# https://i.ytimg.com/vi/cOCXcjbtOOI/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCI-dWJuXvGpDHfJvKXf_ra2htjlA
# https://www.youtube.com/watch?v=cOCXcjbtOOI
# ------------------------------------------------------------
# NEW 뽀로로 9기⭐ 20화 잠 못드는 밤 | 유튜브 최초공개 | 뽀로로 이야기 | 뽀롱뽀롱뽀로로
# https://i.ytimg.com/vi/jX-S1hdEc7g/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBDMoCH8V6crduI-3rXK_RfaPpMwA
# https://www.youtube.com/watch?v=jX-S1hdEc7g
# ------------------------------------------------------------
# 뽀로로 이야기 | 이야! 여름이다! 물놀이 이야기 모음집 (+1시간) | 티비로 몰아보는 뽀로로 인기 에피소드 | 뽀로로 1시간 이어보기
# https://i.ytimg.com/vi/K4B_yNbg5lQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBa69g21hiEIVzuMxF96bl7Y8RZuw
# https://www.youtube.com/watch?v=K4B_yNbg5lQ
# ------------------------------------------------------------

# %% [markdown]
# # **[실습] 공공데이터포털**
# * https://www.data.go.kr
# * https://www.data.go.kr/data/15058601/openapi.do
# * 김해시 공사 : https://www.gimhae.go.kr/00761/00832/05867.web
# * pip install requests

# %%
import requests
import json
url = "http://www.gimhae.go.kr/openapi/tour/restaurant.do"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/151.0.0.0 Safari/537.36"
    ),
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://www.gimhae.go.kr/",
}


res = requests.get(
    url,
    headers=headers,
    timeout=10
)

print(res.status_code) #200
data = res.json()
# Out:
# 200

# %%
print(data["results"][0]['name'])
print(data["results"][0]['category'])
print(data["results"][0]['phone'])
print(data["results"][0]['address'])
# Out:
# (유)아웃백스테이크하우스코리아 김해신세계점
# 양식
# 02-2054-8365
# 경상남도 김해시 김해대로 2232 (외동) 4층

# %%
for v in data["results"] :
    print(v['name'] , v['category'], v['phone'], v['address'], v['xposition'],  v['yposition']) 
    print("--"*20)
# Out:
# (유)아웃백스테이크하우스코리아 김해신세계점 양식 02-2054-8365 경상남도 김해시 김해대로 2232 (외동) 4층 35.2293396295983 128.872242572055
# ----------------------------------------
# (유)아웃백스테이크하우스코리아 김해점 양식 055-337-6191 경상남도 김해시 내외중앙로 76 (내동)  35.2367156289288 128.867421932123
# ----------------------------------------
# (유)아웃백스테이크하우스코리아 김해점 양식 055-337-6191 경상남도 김해시 내외중앙로 76, 2층 (내동, 서울빌딩) 35.2367156289288 128.867421932123
# ----------------------------------------
# (주)가야유통 장유휴게소 (스넥코너) 한식 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동, 장유휴게소) 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(로띠번) 기타 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) , 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(스넥코너) 기타 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(엔제리너스) 카페 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)김덕규과자점 기타 070-8888-6610 경상남도 김해시 장유로 469 (신문동)  35.1850621204763 128.829596369018
# ----------------------------------------
# (주)스타벅스 김해내동점 카페 055-338-7421 경상남도 김해시 경원로 67 (내동)  35.2371561314489 128.867509360481
# ----------------------------------------
# (주)스타벅스 김해대로DT점 카페 055-338-9826 경상남도 김해시 김해대로 2465 (삼정동)  35.2279428522551 128.896463830438
# ----------------------------------------
