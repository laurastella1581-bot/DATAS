# %% [markdown]
# # **ML 시각화 - plotly**
# * matplotlib : https://matplotlib.org/stable/ , https://wikidocs.net/book/5011
# * seaborn : https://seaborn.pydata.org/
# * plotly : https://plotly.com
# * folium : https://python-visualization.github.io/folium/latest/
# * <b>pip install matplotlib, seaborn, plotly, folium

# %% [markdown]
# > matplotlib : 가장 일반적인 시각화 <br>
# seaborn : matplotlib + 통계 <br>
# plotly : 웹 연동 동적 시각화 <br>
# folium : GIS 지도 시각화

# %% [markdown]
# * 위도 (Latitude): 약 37.4848°경도 (Longitude): 약 126.7831°

# %%
import folium
m = folium.Map(location=(37.4848, 126.7831), zoom_start=15)

folium.Marker(
    location=[37.4848, 126.7831],
    tooltip="풍선도움말",
    popup="<img width=100 height= 100 src='https://www.wooriac.co.kr/images/common/logo.svg'>우리인재개발원",
    icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    location=[37.484056, 126.782528],
    tooltip="부천역",
    popup="부천역...",
    icon=folium.Icon(color="red"),
).add_to(m)


folium.CircleMarker([37.484056, 126.782528], radius=100,color='#3186cc', fill_color='#3186cc', popup='부천역'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5e577730677431afab7f13584b9c024 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5e577730677431afab7f13584b9c024&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5e577730677431afab7f13584b9c024 = L.map(
#                 &quot;map_c5e577730677431afab7f13584b9c024&quot;,
#                 {
#                     center: [37.4848, 126.7831],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2965113a44799acbc3da2cb285a2d930 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2965113a44799acbc3da2cb285a2d930.addTo(map_c5e577730677431afab7f13584b9c024);
#
#
#             var marker_e69a1ea53742a6d067bf6a2b3f2de035 = L.marker(
#                 [37.4848, 126.7831],
#                 {
# }
#             ).addTo(map_c5e577730677431afab7f13584b9c024);
#
#
#             var icon_87db6a001e41bcc48be4724b02e28da0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_69a391c98936875b43c542d86081e630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d7eb1949464fbed4d26b8181a2aa427 = $(`&lt;div id=&quot;html_2d7eb1949464fbed4d26b8181a2aa427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img width=100 height= 100 src=&#x27;https://www.wooriac.co.kr/images/common/logo.svg&#x27;&gt;우리인재개발원&lt;/div&gt;`)[0];
#                 popup_69a391c98936875b43c542d86081e630.setContent(html_2d7eb1949464fbed4d26b8181a2aa427);
#
#
#
#         marker_e69a1ea53742a6d067bf6a2b3f2de035.bindPopup(popup_69a391c98936875b43c542d86081e630)
#         ;
#
#
#
#
#             marker_e69a1ea53742a6d067bf6a2b3f2de035.bindTooltip(
#                 `&lt;div&gt;
#                      풍선도움말
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e69a1ea53742a6d067bf6a2b3f2de035.setIcon(icon_87db6a001e41bcc48be4724b02e28da0);
#
#
#             var marker_eac627a5895795c8b33081e6b0f1466d = L.marker(
#                 [37.484056, 126.782528],
#                 {
# }
#             ).addTo(map_c5e577730677431afab7f13584b9c024);
#
#
#             var icon_91f4c981deead84236ca60874455ca95 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a42eaef7fc8c4340a717012a50e25bf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_120ee029dedf800066aed797c58afb3f = $(`&lt;div id=&quot;html_120ee029dedf800066aed797c58afb3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부천역...&lt;/div&gt;`)[0];
#                 popup_a42eaef7fc8c4340a717012a50e25bf5.setContent(html_120ee029dedf800066aed797c58afb3f);
#
#
#
#         marker_eac627a5895795c8b33081e6b0f1466d.bindPopup(popup_a42eaef7fc8c4340a717012a50e25bf5)
#         ;
#
#
#
#
#             marker_eac627a5895795c8b33081e6b0f1466d.bindTooltip(
#                 `&lt;div&gt;
#                      부천역
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_eac627a5895795c8b33081e6b0f1466d.setIcon(icon_91f4c981deead84236ca60874455ca95);
#
#
#             var circle_marker_268b7297bccfb22259d2be170ade9c86 = L.circleMarker(
#                 [37.484056, 126.782528],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e577730677431afab7f13584b9c024);
#
#
#         var popup_6dd2f98457b7c40f749c0cbf05aa2a93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# # **마커 클러스터**

# %%
import numpy as np
from folium import plugins

N = 100
data = np.array(
[
np.random.uniform(low=36, high=38, size=N), # Random latitudes.
np.random.uniform(low=127, high=128, size=N), # Random longitudes.
] ).T

print(data[:3])
popups = [str(i) for i in range(N)] # Popups texts are simple numbers.


m = folium.Map([37.566345, 126.977893], zoom_start=8)
plugins.MarkerCluster(data, popups=popups).add_to(m)
m
# Out:
# [[ 36.85570475 127.49576605]
#  [ 36.67225754 127.54607151]
#  [ 37.91035932 127.35716679]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1a74a42c8365e584138cceadff1ed57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1a74a42c8365e584138cceadff1ed57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1a74a42c8365e584138cceadff1ed57 = L.map(
#                 &quot;map_e1a74a42c8365e584138cceadff1ed57&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_999a3f85cd66fa1b86473d6751f658c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_999a3f85cd66fa1b86473d6751f658c7.addTo(map_e1a74a42c8365e584138cceadff1ed57);
#
#
#             var marker_cluster_bd7fbee315dee4ae8d079a26ff720052 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_3a5cff299088b02af2ffe09e88ccc679 = L.marker(
#                 [36.855704750921895, 127.49576604823984],
#                 {
# }
#             ).addTo(marker_cluster_bd7fbee315dee4ae8d079a26ff720052);
#
#
#         var popup_543f36c9b1730be57bab22a14aa0706b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_388b2569eec6118361b0163d15a202da = $(`&lt;div id=&quot;html_388b2569eec6118361b0163d15a202da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_543f36c9b1730be57bab22a14aa0706b.setContent(html_388b2569eec6118361b0163d15a202da);
#
#
#
#         marker_3a5cff299088b02af2ffe09e88ccc679.bindPopup(popup_543f36c9b1730be57bab22a14aa0706b)
#         ;
#
#
#
#
#             var marker_e8424bff21982927183a051c8d39e277 = L.marker(
#                 [36.67225754325309, 127.54607150532264],
#                 {
# }
#             ).addTo(marker_cluster_bd7fbee315dee4ae8d079a26ff720052);
#
#
#         var popup_3b05e41aa6773555f618bd436329a0cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a994d58e90c2b6c1889cffc5b1084f33 = $(`&lt;div id=&quot;html_a994d58e90c2b6c1889cffc5b1084f33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_3b05e41aa6773555f618bd436329a0cd.setContent(html_a994d58e90c2b6c1889cffc5b1084f33);
#
#
#
#         marker_e8424bff21982927183a051c8d39e277.bindPopup(popup_3b05e41aa6773555f618bd436329a0cd)
#         ;
#
#
#
#
#             var marker_a48cb75b9fad9e9405c5d8e5fdec91dc = L.marker(
#                 [37.910359323892145, 127.3571667894135],
#                 {
# }
#             ).addTo(marker_cluster_bd7fbee315dee4ae8d079a26ff720052);
#
#
#         var popup_11313551a55d4d03cc912870c41f88bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6d55c28748725e01a70ee0245f1b30 = $(`&lt;div id=&quot;html_ac6d55c28748725e01a70ee0245f1b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_11313551a55d4d03cc912870c41f88bc.setContent(html_ac6d55c28748725e01a70ee0245f1b30);
#
#
#
#         marker_a48cb75b9fad9e9405c5d8e5fdec91dc.bindPopup(popup_11313551a55d4d03cc912870c41f88bc)
#         ;
#
#
#
#
#             var marker_fb7d5b813544d20462b0f592bc30ce69 = L.marker(
#                 [36.70104767251361, 127.5375528507451],
#                 {
# }
#             ).addTo(marker_cluster_bd7fbee315dee4ae8d079a26ff720052);
#
#
#         var popup_243a4ae5034025539e8db0a960d4ee12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed39be6cb501a3cf1f1b88959aab0473 = $(`&lt;div id=&quot;html_ed39be6cb501a3cf1f1b88959aab0473&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_243a4ae5034025539e8db0a960d4ee12.setContent(html_ed39be6cb501a3cf1f1b88959aab0473);
#
#
#
#         marker_fb7d5b813544d20462b0f592bc30ce69.bindPopup(popup_243a4ae5034025539e8db0a960d4ee12)
#         ;
#
#
#
#
#             var marker_4ac01e99de72f461fb

# %% [markdown]
# # **[실습]**
# * jeju.csv

# %%
import numpy as np
import pandas as pd
from folium import plugins
import folium

# %%
df = pd.read_csv("../datas/jeju.csv")
df.head(2)
# Out:
#           name gubun             tel        lat         lng  \
# 0        우진해장국    한식    064-757-3393  33.511488  126.520086
# 1  고집돌우럭 제주공항점   해산물  0507-1436-1008  33.517300  126.526600
#
#                  addr                                                img
# 0  제주특별자치도 제주시 서사로 11  https://lh3.googleusercontent.com/grass-cs/ACv...
# 1  제주특별자치도 제주시 임항로 30  https://lh3.googleusercontent.com/grass-cs/ACv...

# %%
data = df[['lat','lng']].values
print(data )
# Out:
# [[ 33.511488 126.520086]
#  [ 33.5173   126.5266  ]
#  [ 33.486    126.4935  ]
#  [ 33.5104   126.516   ]
#  [ 33.5017   126.5425  ]
#  [ 33.515    126.526   ]
#  [ 33.515    126.507   ]
#  [ 33.512    126.518   ]
#  [ 33.465    126.322   ]
#  [ 33.5125   126.526   ]]

# %%
df.shape[0]
# Out:
# 10

# %%
popups = ("<b>" + df['name'] + "</b><br>" + df['tel'] + "<br>"+df['addr']+"<br><img src='"+df['img']+"' width=100>" ).tolist()
#print(popups)

m = folium.Map([33.511, 126.493], zoom_start=9)
plugins.MarkerCluster(data, popups=popups).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_238d6f16c794d5e73b2bd3454f2cec2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_238d6f16c794d5e73b2bd3454f2cec2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_238d6f16c794d5e73b2bd3454f2cec2c = L.map(
#                 &quot;map_238d6f16c794d5e73b2bd3454f2cec2c&quot;,
#                 {
#                     center: [33.511, 126.493],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5415d18da46d07669a94b46b6414583c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5415d18da46d07669a94b46b6414583c.addTo(map_238d6f16c794d5e73b2bd3454f2cec2c);
#
#
#             var marker_cluster_52e37aff38d7abb744fe886587eda443 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_85a6aaab246aa58434235152b8c532b1 = L.marker(
#                 [33.511488, 126.520086],
#                 {
# }
#             ).addTo(marker_cluster_52e37aff38d7abb744fe886587eda443);
#
#
#         var popup_267cdb053a412c2bcd70a0b367f98c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7839c8f14e013813b9a493982855b6ea = $(`&lt;div id=&quot;html_7839c8f14e013813b9a493982855b6ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;우진해장국&lt;/b&gt;&lt;br&gt;064-757-3393&lt;br&gt;제주특별자치도 제주시 서사로 11&lt;br&gt;&lt;img src=&#x27;https://lh3.googleusercontent.com/grass-cs/ACvplmPxABxQZfV51mSABNzylithWU-uilEjWPCx4mTdX12EqWvPHrzqADETHJGiJq4Bub5d22Jdy-7vRIgHvlDh6QYVWRrqKKTGprY56lkoacTt5i9AJMDm2v1JlG196iozuXlS2OiZJ57r5G-1=w326-h312-n-k-no&#x27; width=100&gt;&lt;/div&gt;`)[0];
#                 popup_267cdb053a412c2bcd70a0b367f98c83.setContent(html_7839c8f14e013813b9a493982855b6ea);
#
#
#
#         marker_85a6aaab246aa58434235152b8c532b1.bindPopup(popup_267cdb053a412c2bcd70a0b367f98c83)
#         ;
#
#
#
#
#             var marker_67e6c9fa9111db651e1c94f57d860ef1 = L.marker(
#                 [33.5173, 126.5266],
#                 {
# }
#             ).addTo(marker_cluster_52e37aff38d7abb744fe886587eda443);
#
#
#         var popup_c7ebbcf21827deb910005ab08a7ef91f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b708217edf23e2fbebb00e170ff1fad = $(`&lt;div id=&quot;html_2b708217edf23e2fbebb00e170ff1fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;고집돌우럭 제주공항점&lt;/b&gt;&lt;br&gt;0507-1436-1008&lt;br&gt;제주특별자치도 제주시 임항로 30&lt;br&gt;&lt;img src=&#x27;https://lh3.googleusercontent.com/grass-cs/ACvplmPgruzMof3Bl39FbK2TPEQhW1YGlFi007jihKatTSkiow1rPd11UwOXcy7vX-wWqY08DBsn8EmwGuFzsE1tx12Fq4MxNBrI8WWGYKlep3BbOeUokth2fAx-TTqEL1zXIZRxpew=w326-h312-n-k-no&#x27; width=100&gt;&lt;/div&gt;`)[0];
#                 popup_c7ebbcf21827deb910005ab08a7ef91f.setContent(html_2b708217edf23e2fbebb00e170ff1fad);
#
#
#
#         marker_67e6c9fa9111db651e1c94f57d860ef1.bindPopup(popup_c7ebbcf21827deb910005ab08a7ef91f)
#         ;
#
#
#
#
#             var marker_e8f55fad45805d15e71eb75de46b5785 = L.marker(
#                 [33.486, 126.4935],
#                 {
# }
#             ).addTo(marker_cluster_52e37aff38d7abb744fe886587eda443);
#
#
#         var popup_3ba301b6005c15fcf2d1b14846f24a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1523f20749b23d73a72d0ff4086966fa = $(`&lt;div id=&quot;html_1523f20749b23d73a72d0ff4086966fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;돌담흑돼지 연동본점&lt;/b&gt;&lt;br&gt;064-742-7355&lt;br&gt;제주특별자치도 제주시 연동7길 35, 2층&lt;br&gt;&lt;img src=&#x27;https://lh3.googleusercontent.com/grass-cs/ACvplmMBO7PGn14LHxQ_RZesb5WbK-H4M0ejfVHesC9UPM-BmSB-xeSMSdbSqoOsl1V-fN96WsLTfCihYj-K1sL9eS8NR7unxlQi1I0_iWn3n0vCAe2wxGlTaG3So_oMV0c-FgWMT_Cd=w326-h312-n-k-no&#x27; width=100&gt;&lt;/div&gt;`)[0];
#                 popup_3ba301b6005c15fcf2d1b14846f24a32.setContent(html_1523f20749b23d73a72d0ff4086966fa);
#
#
#
#         marker_e8f55fad45805d15e71eb75de46b5785.bindPopup(
