# %%
names = ["영택", "철수", "민수"]

for name in names:
    print(name)
# Out:
# 영택
# 철수
# 민수

# %%
fruits = ["사과", "바나나", "포도"]

for fruit in fruits:
    print(fruit)
# Out:
# 사과
# 바나나
# 포도

# %%
numbers = [1, 2, 3, 4]

for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
names = ["철수", "영희"]

for name in names:
    print("안녕하세요", name)
# Out:
# 안녕하세요 철수
# 안녕하세요 영희

# %%
numbers = [10, 20, 30]

for num in numbers:
    print(num + 5)
# Out:
# 15
# 25
# 35

# %%
foods = ["피자", "햄버거", "치킨"]

for food in foods:
    print("나는", food, "좋아해")
# Out:
# 나는 피자 좋아해
# 나는 햄버거 좋아해
# 나는 치킨 좋아해

# %%
for i in range(2, 11, 2):       # 2부터 10까지 2씩 커지면서 숫자 꺼내기
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
